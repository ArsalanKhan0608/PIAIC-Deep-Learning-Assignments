# %% [markdown]
# # Assignment: Ionosphere Data Problem
#
# ### Dataset Description:
#
# This radar data was collected by a system in Goose Bay, Labrador. This system consists of a phased array of 16 high-frequency antennas with a total transmitted power on the order of 6.4 kilowatts. See the paper for more details. The targets were free electrons in the ionosphere. "Good" radar returns are those showing evidence of some type of structure in the ionosphere. "Bad" returns are those that do not; their signals pass through the ionosphere.
#
# Received signals were processed using an autocorrelation function whose arguments are the time of a pulse and the pulse number. There were 17 pulse numbers for the Goose Bay system. Instances in this databse are described by 2 attributes per pulse number, corresponding to the complex values returned by the function resulting from the complex electromagnetic signal.
#
# ### Attribute Information:
#
# - All 34 are continuous
# - The 35th attribute is either "good" or "bad" according to the definition summarized above. This is a binary classification task.
#
#  <br><br>
#
# <table border="1"  cellpadding="6">
# 	<tbody>
#         <tr>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Data Set Characteristics:&nbsp;&nbsp;</b></p></td>
# 		<td><p class="normal">Multivariate</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Number of Instances:</b></p></td>
# 		<td><p class="normal">351</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Area:</b></p></td>
# 		<td><p class="normal">Physical</p></td>
#         </tr>
#      </tbody>
#     </table>
# <table border="1" cellpadding="6">
#     <tbody>
#         <tr>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Attribute Characteristics:</b></p></td>
#             <td><p class="normal">Integer,Real</p></td>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Number of Attributes:</b></p></td>
#             <td><p class="normal">34</p></td>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Date Donated</b></p></td>
#             <td><p class="normal">N/A</p></td>
#         </tr>
#      </tbody>
#     </table>
# <table border="1" cellpadding="6">
#     <tbody>
#     <tr>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Associated Tasks:</b></p></td>
# 		<td><p class="normal">Classification</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Missing Values?</b></p></td>
# 		<td><p class="normal">N/A</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Number of Web Hits:</b></p></td>
# 		<td><p class="normal">N/A</p></td>
# 	</tr>
#     </tbody>
#     </table>

# %% [markdown]
# ### WORKFLOW :
# - Load Data
# - Check Missing Values ( If Exist ; Fill each record with mean of its feature ) or any usless column.
# - Shuffle the data if needed.
# - Standardized the Input Variables. **Hint**: Centeralized the data
# - Split into 60 and 40 ratio.
# - Encode labels.
# - Model : 1 hidden layers including 16 unit.
# - Compilation Step (Note : Its a Binary problem , select loss , metrics according to it)
# - Train the Model with Epochs (100).
# - If the model gets overfit tune your model by changing the units , No. of layers , epochs , add dropout layer or add Regularizer according to the need .
# - Prediction should be > **92%**
# - Evaluation Step
# - Prediction

# %% [markdown]
# # Load Data:
# [Click Here to Download DataSet](https://github.com/ramsha275/ML_Datasets/blob/main/ionosphere_data.csv)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Importing Modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import  to_categorical
from sklearn.preprocessing import scale, LabelEncoder

# %%
# Loding Dataset
df = pd.read_csv("/content/drive/MyDrive/ML_Datasets/ionosphere_data.csv")
df
# Out:
#      feature1  feature2  feature3  ...  feature33  feature34  label
# 0           1         0   0.99539  ...    0.18641   -0.45300      g
# 1           1         0   1.00000  ...   -0.13738   -0.02447      b
# 2           1         0   1.00000  ...    0.56045   -0.38238      g
# 3           1         0   1.00000  ...   -0.32382    1.00000      b
# 4           1         0   1.00000  ...   -0.04608   -0.65697      g
# ..        ...       ...       ...  ...        ...        ...    ...
# 346         1         0   0.83508  ...    0.90546   -0.04307      g
# 347         1         0   0.95113  ...    0.91483    0.04712      g
# 348         1         0   0.94701  ...    0.92697   -0.00577      g
# 349         1         0   0.90608  ...    0.87403   -0.16243      g
# 350         1         0   0.84710  ...    0.85764   -0.06151      g
#
# [351 rows x 35 columns]

# %%
# Visualizing The Data
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
plt.title('Label Distribution Plot')
sns.distplot(df.label)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Checking For Null Values
df.isnull().sum()
# Out:
# feature1     0
# feature2     0
# feature3     0
# feature4     0
# feature5     0
# feature6     0
# feature7     0
# feature8     0
# feature9     0
# feature10    0
# feature11    0
# feature12    0
# feature13    0
# feature14    0
# feature15    0
# feature16    0
# feature17    0
# feature18    0
# feature19    0
# feature20    0
# feature21    0
# feature22    0
# feature23    0
# feature24    0
# feature25    0
# feature26    0
# feature27    0
# feature28    0
# feature29    0
# feature30    0
# feature31    0
# feature32    0
# feature33    0
# feature34    0
# label        0
# dtype: int64

# %% [markdown]
# ### OUR DATA CONTAINS NO NULL VALUES

# %%
# Making A HeatMap of Correlations
correlations = df.corr()
plt.figure(figsize=(20,16))
sns.heatmap(correlations, cmap="CMRmap_r", annot = True)
plt.show()

# %%
# Class Distribution Plot
plt.figure(figsize=(10,10))
plt.title("Class Distribution Plot")
sns.countplot(x='label', data=df)

# %% [markdown]
# ### The Dataset Is **Imbalance** But It's Not Too Much So, I Am Going To **Ignore** It.

# %%
# Droping Unecessary Columns
df = df.drop('feature2', axis=1)

# %%
# One Hot Enconding Labels
encoding = {'g': 1, 'b': 0}
df.label.replace(encoding, inplace=True)

# %%
# Shuffling Data
df = df.sample(frac = 1)
df
# Out:
#      feature1  feature3  feature4  ...  feature33  feature34  label
# 46          1   1.00000  -0.03730  ...    0.75115   -0.50152      1
# 229         1   0.73523  -0.38293  ...    0.30588    0.49831      1
# 9           1  -0.01864  -0.08459  ...   -0.08208    0.38065      0
# 296         1   0.88116   0.27475  ...   -0.19312   -0.75597      1
# 339         1   0.65845   0.43617  ...   -0.18533    0.74356      1
# ..        ...       ...       ...  ...        ...        ...    ...
# 120         1   0.43636  -0.12727  ...    0.29091   -0.29091      0
# 19          0   1.00000  -1.00000  ...    1.00000    1.00000      0
# 247         1   0.49870   0.01818  ...    0.58961   -0.08571      1
# 292         1   0.84713  -0.03397  ...    0.65817   -0.24841      1
# 198         1   0.36876  -1.00000  ...    0.00015    0.00325      0
#
# [351 rows x 34 columns]

# %%
# Splitting The Dataset Into Training And Testing Data

# Training Data
train_data = df.iloc[:211,:]
train_data
# Out:
#      feature1  feature3  feature4  ...  feature33  feature34  label
# 46          1   1.00000  -0.03730  ...    0.75115   -0.50152      1
# 229         1   0.73523  -0.38293  ...    0.30588    0.49831      1
# 9           1  -0.01864  -0.08459  ...   -0.08208    0.38065      0
# 296         1   0.88116   0.27475  ...   -0.19312   -0.75597      1
# 339         1   0.65845   0.43617  ...   -0.18533    0.74356      1
# ..        ...       ...       ...  ...        ...        ...    ...
# 318         1   0.74790   0.00840  ...    0.55330    0.08891      1
# 140         1   0.94531  -0.03516  ...   -1.00000   -0.34375      0
# 54          1   0.95659   0.08143  ...    0.82166   -0.41173      1
# 159         1   0.94333   0.38574  ...   -0.21572    0.50457      1
# 121         1   1.00000  -0.92453  ...    0.43396   -0.11321      1
#
# [211 rows x 34 columns]

# %%
# Testing Data
test_data = df.iloc[211:,:]
test_data
# Out:
#      feature1  feature3  feature4  ...  feature33  feature34  label
# 125         1   0.95217   0.06595  ...    0.18632    0.37191      1
# 317         1   1.00000  -0.24051  ...    0.83544   -0.02532      1
# 18          1   0.67065   0.02528  ...    1.00000    0.33036      1
# 101         1   1.00000   0.01709  ...    0.87011   -0.23296      1
# 233         1   0.50466  -0.16900  ...    0.54632    0.09346      1
# ..        ...       ...       ...  ...        ...        ...    ...
# 120         1   0.43636  -0.12727  ...    0.29091   -0.29091      0
# 19          0   1.00000  -1.00000  ...    1.00000    1.00000      0
# 247         1   0.49870   0.01818  ...    0.58961   -0.08571      1
# 292         1   0.84713  -0.03397  ...    0.65817   -0.24841      1
# 198         1   0.36876  -1.00000  ...    0.00015    0.00325      0
#
# [140 rows x 34 columns]

# %%
# Dropping Labels From Training And Testing Data

# Train Labels
train_labels = train_data.pop('label')
train_labels
# Out:
# 46     1
# 229    1
# 9      0
# 296    1
# 339    1
#       ..
# 318    1
# 140    0
# 54     1
# 159    1
# 121    1
# Name: label, Length: 211, dtype: int64

# %%
# Test Labels
test_labels = test_data.pop('label')
test_labels
# Out:
# 125    1
# 317    1
# 18     1
# 101    1
# 233    1
#       ..
# 120    0
# 19     0
# 247    1
# 292    1
# 198    0
# Name: label, Length: 140, dtype: int64

# %%
# Standardizing Training And Testing Data
from sklearn.preprocessing import StandardScaler
train_data = StandardScaler().fit_transform(train_data)
train_data
# Out:
# array([[ 0.37488737,  0.68842263, -0.18176899, ..., -0.97403328,
#          0.77483017, -1.10696325],
#        [ 0.37488737,  0.15532241, -0.95682396, ...,  0.93397962,
#         -0.06305654,  1.04907163],
#        [ 0.37488737, -1.36255447, -0.28781404, ...,  0.43333569,
#         -0.79310018,  0.79534944],
#        ...,
#        [ 0.37488737,  0.60101892,  0.08447606, ..., -0.79990645,
#          0.90751235, -0.91333996],
#        [ 0.37488737,  0.57432062,  0.76687335, ...,  1.02690194,
#         -1.04457722,  1.06257071],
#        [ 0.37488737,  0.68842263, -2.17133015, ...,  0.81045425,
#          0.17795797, -0.26961099]])

# %%
test_data = StandardScaler().fit_transform(test_data)
test_data
# Out:
# array([[ 0.30618622,  0.67695017,  0.04770501, ...,  0.84802874,
#         -0.35131064,  0.7463811 ],
#        [ 0.30618622,  0.77329587, -0.66014236, ...,  0.12385079,
#          0.92928119, -0.09252627],
#        [ 0.30618622,  0.10987427, -0.04623271, ...,  0.57802408,
#          1.25392716,  0.65863194],
#        ...,
#        [ 0.30618622, -0.23649083, -0.06263196, ..., -0.03210287,
#          0.44430478, -0.2200635 ],
#        [ 0.30618622,  0.46536431, -0.18308566, ..., -0.6635131 ,
#          0.57956078, -0.56366854],
#        [ 0.30618622, -0.49823367, -2.4143778 , ...,  0.07651992,
#         -0.71858908, -0.03218948]])

# %%
n_features = train_data.shape[1]
n_features
# Out:
# 33

# %%
# Making Base Model
model = Sequential()
model.add(Dense(16, activation='relu', input_shape = (n_features,)))
model.add(Dropout(0.2))
model.add(Dense(12, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation = 'relu'))
model.add(Dense(8, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(6, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ### I have used **Dropout Layers** to make sure that the model does not get **Overfit** during **Training**

# %%
# Compilation Step
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_58 (Dense)             (None, 16)                544
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_59 (Dense)             (None, 12)                204
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 12)                0
# _________________________________________________________________
# dense_60 (Dense)             (None, 10)                130
# _________________________________________________________________
# dense_61 (Dense)             (None, 8)                 88
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_62 (Dense)             (None, 6)                 54
# _________________________________________________________________
# dense_63 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 1,027
# Trainable params: 1,027
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fitting Model On 100 Epochs
history = model.fit(train_data, train_labels, epochs = 100, batch_size = 8)
# Out:
# Epoch 1/100
# 27/27 [==============================] - 1s 2ms/step - loss: 0.6949 - accuracy: 0.3830
# Epoch 2/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6866 - accuracy: 0.6676
# Epoch 3/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6773 - accuracy: 0.6856
# Epoch 4/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6732 - accuracy: 0.6030
# Epoch 5/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6317 - accuracy: 0.7073
# Epoch 6/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5832 - accuracy: 0.7114
# Epoch 7/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5098 - accuracy: 0.7647
# Epoch 8/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4803 - accuracy: 0.7723
# Epoch 9/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.5187 - accuracy: 0.7596
# Epoch 10/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4580 - accuracy: 0.8253
# Epoch 11/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4770 - accuracy: 0.8268
# Epoch 12/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4396 - accuracy: 0.8253
# Epoch 13/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3353 - accuracy: 0.8696
# Epoch 14/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3365 - accuracy: 0.9025
# Epoch 15/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3062 - accuracy: 0.8852
# Epoch 16/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2463 - accuracy: 0.9286
# Epoch 17/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2994 - accuracy: 0.8705
# Epoch 18/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1746 - accuracy: 0.9392
# Epoch 19/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2147 - accuracy: 0.9310
# Epoch 20/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2219 - accuracy: 0.9196
# Epoch 21/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2673 - accuracy: 0.8992
# Epoch 22/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1577 - accuracy: 0.9624
# Epoch 23/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1627 - accuracy: 0.9563
# Epoch 24/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1847 - accuracy: 0.9283
# Epoch 25/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1642 - accuracy: 0.9173
# Epoch 26/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1460 - accuracy: 0.9582
# Epoch 27/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2163 - accuracy: 0.9174
# Epoch 28/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1755 - accuracy: 0.9362
# Epoch 29/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1541 - accuracy: 0.9303
# Epoch 30/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1530 - accuracy: 0.9284
# Epoch 31/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0965 - accuracy: 0.9626
# Epoch 32/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1360 - accuracy: 0.9511
# Epoch 33/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1559 - accuracy: 0.9615
# Epoch 34/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1148 - accuracy: 0.9698
# Epoch 35/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1243 - accuracy: 0.9587
# Epoch 36/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1515 - accuracy: 0.9399
# Epoch 37/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1042 - accuracy: 0.9758
# Epoch 38/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0806 - accuracy: 0.9752
# Epoch 39/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1229 - accuracy: 0.9683
# Epoch 40/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1319 - accuracy: 0.9517
# Epoch 41/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1916 - accuracy: 0.9018
# Epoch 42/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1093 - accuracy: 0.9756
# Epoch 43/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1304 - accuracy: 0.9605
# Epoch 44/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0963 - accuracy: 0.9713
# Epoch 45/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0754 - accuracy: 0.9614
# Epoch 46/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1035 - accuracy: 0.9490
# Epoch 47/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0935 - accuracy: 0.9435
# Epoch 48/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1552 - accuracy: 0.9550
# Epoch 49/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0743 - accuracy: 0.9664
# Epoch 50/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0629 - accuracy: 0.9915
# Epoch 51/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1071 - accuracy: 0.9465
# Epoch 52/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0914 - accuracy: 0.9661
# Epoch 53/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0716 - accuracy: 0.9707
# Epoch 54/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0799 - accuracy: 0.9628
# Epoch 55/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0623 - accuracy: 0.9869
# Epoch 56/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0445 - accuracy: 0.9826
# Epoch 57/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0766 - accuracy: 0.9751
# Epoch 58/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1023 - accuracy: 0.9567
# Epoch 59/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1031 - accuracy: 0.9443
# Epoch 60/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1225 - accuracy: 0.9696
# Epoch 61/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1222 - accuracy: 0.9285
# Epoch 62/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0543 - accuracy: 0.9699
# Epoch 63/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0369 - accuracy: 0.9882
# Epoch 64/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0613 - accuracy: 0.9717
# Epoch 65/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1062 - accuracy: 0.9570
# Epoch 66/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0771 - accuracy: 0.9675
# Epoch 67/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1192 - accuracy: 0.9358
# Epoch 68/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0787 - accuracy: 0.9553
# Epoch 69/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0523 - accuracy: 0.9750
# Epoch 70/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0461 - accuracy: 0.9711
# Epoch 71/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0373 - accuracy: 0.9799
# Epoch 72/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0428 - accuracy: 0.9817
# Epoch 73/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0724 - accuracy: 0.9620
# Epoch 74/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1226 - accuracy: 0.9629
# Epoch 75/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0415 - accuracy: 0.9733
# Epoch 76/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1456 - accuracy: 0.9462
# Epoch 77/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0411 - accuracy: 0.9769
# Epoch 78/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0435 - accuracy: 0.9864
# Epoch 79/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0677 - accuracy: 0.9779
# Epoch 80/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0811 - accuracy: 0.9569
# Epoch 81/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0592 - accuracy: 0.9784
# Epoch 82/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0580 - accuracy: 0.9785
# Epoch 83/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0240 - accuracy: 0.9993
# Epoch 84/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0335 - accuracy: 0.9830
# Epoch 85/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0205 - accuracy: 0.9960
# Epoch 86/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0624 - accuracy: 0.9668
# Epoch 87/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0826 - accuracy: 0.9706
# Epoch 88/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0921 - accuracy: 0.9772
# Epoch 89/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0630 - accuracy: 0.9679
# Epoch 90/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0318 - accuracy: 0.9832
# Epoch 91/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0411 - accuracy: 0.9683
# Epoch 92/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0718 - accuracy: 0.9669
# Epoch 93/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0353 - accuracy: 0.9935
# Epoch 94/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0300 - accuracy: 0.9975
# Epoch 95/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0244 - accuracy: 0.9921
# Epoch 96/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0842 - accuracy: 0.9912
# Epoch 97/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0223 - accuracy: 0.9963
# Epoch 98/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1415 - accuracy: 0.9433
# Epoch 99/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0854 - accuracy: 0.9724
# Epoch 100/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1060 - accuracy: 0.9715

# %%
# Feeding History In A DataFrame
history_df = pd.DataFrame(history.history)
history_df['epoch'] = history.epoch
history_df.tail()
# Out:
#         loss  accuracy  epoch
# 95  0.077012  0.990521     95
# 96  0.027379  0.995261     96
# 97  0.112045  0.966825     97
# 98  0.067419  0.985782     98
# 99  0.067885  0.985782     99

# %%
# Plotting Loss And Accuracy
plt.figure(figsize=(10,10))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title("Model Training Loss")
plt.plot(history_df['epoch'], history_df['loss'], color = 'blue')
plt.grid()

plt.figure(figsize=(10,10))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title("Model Training Accuracy")
plt.plot(history_df['epoch'], history_df['accuracy'], color = 'red')
plt.grid()
plt.show()

# %%
# Making Predictions On Test Data
predictions = model.predict(test_data)
predictions[:10]
# Out:
# array([[0.99491507],
#        [0.9793917 ],
#        [0.06604102],
#        [0.9984348 ],
#        [0.9931808 ],
#        [0.99808645],
#        [0.9987202 ],
#        [0.99320424],
#        [0.99137986],
#        [0.9938009 ]], dtype=float32)

# %%
# Testing Model On Test Data
testing = model.evaluate(test_data, test_labels)
testing
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2314 - accuracy: 0.9429
# [0.23139308393001556, 0.9428571462631226]

# %%
# Making Classification Report
from sklearn.metrics import classification_report
model_classification_report = classification_report(test_labels, predictions.round(), output_dict=True)

# %%
classification_report_df = pd.DataFrame(model_classification_report)
classification_report_df
# Out:
#                    0          1  accuracy   macro avg  weighted avg
# precision   0.903846   0.965909  0.942857    0.934878      0.943744
# recall      0.940000   0.944444  0.942857    0.942222      0.942857
# f1-score    0.921569   0.955056  0.942857    0.938312      0.943096
# support    50.000000  90.000000  0.942857  140.000000    140.000000

# %%
# Testing Loss And Testing Accuracy
print(f"Testing Loss: {testing[0]}")
print(f"Testing Accuracy: {testing[1]}")
# Out:
# Testing Loss: 0.23139308393001556
# Testing Accuracy: 0.9428571462631226

# %%
# Saving Model
model.save('IonosphereModel.h5')

# %%
# Exporting Model In CSV File
from google.colab import files
df.to_csv('Ionosphere_Model.csv', index=False)
files.download('Ionosphere_Model.csv')
print("Your File Was Saved Successfully!")
# Out:
# Your File Was Saved Successfully!
